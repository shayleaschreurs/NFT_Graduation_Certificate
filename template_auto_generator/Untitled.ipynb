# %%
pip install pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from PIL import Image, ImageDraw, ImageFont

# %%
df = pd.read_csv('Untitled spreadsheet - Sheet1.csv', index_col = 'Id')

# %%
df
# Out:
#              Name
# Id
# 1   Dog Yorkshire
# 2       Cat Tabby
# 3    Sloth Speedy

# %%
font = ImageFont.truetype('Open_Sans/OpenSans-Italic-VariableFont_wdth,wght.ttf', size=30)

# %%
template = Image.open('certificate-template.png')
pic = Image.open('CAT.png').resize((170,170), Image.ANTIALIAS)
draw = ImageDraw.Draw(template)

# %%
draw.text((505, 505), 'Cat Tabby', font=font, fill='black')

# %%
Image.open('CAT.png').resize((170,170), Image.ANTIALIAS)
# Out:
# <PIL.Image.Image image mode=RGBA size=170x170 at 0x7F9B08148150>

# %%
template.paste(pic, (311, 452, 481, 622))

# %%
template
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1074x708 at 0x7F9B314D3D90>
